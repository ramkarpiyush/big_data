# %% [markdown]
# Incremental data load:
# 1. Only process new data files
# 2. Process the data load asap new data detected
# 3. dont miss any new files
# 4. Good performnace while processing layer directories
# 5. repeatable pattern

# %% [markdown]
# Common patterns of incremental data loading:
# 1. Water mark method:
#   - Program will keep on running to check if any file arrived, though no new files.
# 2. Checkpointing
#   - Performance bottleneck while listing larger directories

# %% [markdown]
# **AutoLoader:**
# - Continuosly, efficiently, automatically loading new files as they arrive.
# - Components:
#   -
