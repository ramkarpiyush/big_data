# %%
df = spark.read.option("header", "true").csv("/Volumes/my_catalog/my_schema/csv/dim_customers2.csv")
# df.count()
df.limit(5).display()

# %%
from delta.tables import *
dt = DeltaTable.forpath(spark, "my_catalog.marsh_bi.dim_customers")

# %%
df.optimize().executeZOrderBy("CustomerKey", "BirthDate")
