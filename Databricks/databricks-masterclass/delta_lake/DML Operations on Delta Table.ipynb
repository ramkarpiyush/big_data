# %%
# %fs ls /Workspace/Users/ramkarpiyush@gmail.com/big_data/Databricks/databricks-masterclass/data/shoppinginvoices

# %%
files = dbutils.fs.ls("/Workspace/Users/ramkarpiyush@gmail.com/big_data/Databricks/databricks-masterclass/data/shoppinginvoices")
display(files)

# %%
# %sql
CREATE CATALOG IF NOT EXISTS deltacatalog;

# %%
# %sql
CREATE SCHEMA IF NOT EXISTS deltacatalog.deltadb;

# %%
# %sql
SHOW CATALOGS;

# %%
# %sql
DESCRIBE CATALOG deltacatalog;

# %%
# %sql
SHOW SCHEMAS IN deltacatalog;

# %%
# %sql
SHOW TABLES IN deltacatalog.deltadb;

# %%
# %sql
SELECT * FROM PARQUET.`/Volumes/deltacatalog/deltadb/deltavolume/invoices_101_200.parquet`
LIMIT 5;

# %%
# %sql
CREATE OR REPLACE TABLE deltacatalog.deltadb.invoices
AS 
SELECT * FROM PARQUET.`/Volumes/deltacatalog/deltadb/deltavolume/invoices_101_200.parquet`;

# %%
# %sql
SELECT * FROM deltacatalog.deltadb.invoices

# %%
# %sql
DESCRIBE HISTORY deltacatalog.deltadb.invoices;
