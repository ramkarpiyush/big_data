# %% [markdown]
# # # Read Using PySpark

# %%
from pyspark.sql import SparkSession
import os
from loguru import logger
from pyspark.sql.functions import count
import re

spark = SparkSession.builder \
    .appName("Load-CSV-Pg")\
    .config("spark.jars.packages", "org.postgresql:postgresql:42.6.0")\
    .getOrCreate() 

jdbc_url = "jdbc:postgresql://localhost:5432/postgres"

properties = {
    "user": "postgres",
    "password": "postgres",
    "driver": "org.postgresql.Driver"
}

# %%
df = spark.read.jdbc(
    url=jdbc_url,
    table="myschema.products",
    properties=properties
)
df.show(1)
# Out:
# +------+--------------------+--------------------+---------------+--------+-----+--------+-----+-------------+------+----------+------------+-----------+
# | Index|                Name|         Description|          Brand|Category|Price|Currency|Stock|          EAN| Color|      Size|Availability|Internal ID|
# +------+--------------------+--------------------+---------------+--------+-----+--------+-----+-------------+------+----------+------------+-----------+
# |769551|Advanced Scale He...|Specific simple r...|Barton-Arellano| Cycling|  926|     USD|  648|1571405406951|Tomato|100x200 mm|    in_stock|         33|
# +------+--------------------+--------------------+---------------+--------+-----+--------+-----+-------------+------+----------+------------+-----------+
# only showing top 1 row

# %% [markdown]
# #### Using .format("jdbc") (Enterprise Method)

# %%
df = (
    spark.read.format("jdbc")
    .option("url", jdbc_url)
    .option("dbtable", "myschema.products")
    .option("user", "postgres")
    .option("password", "postgres")
    .option("driver", "org.postgresql.Driver")
    .option("partitionColumn", "Index")     # Must be numeric column
    .option("lowerBound", 1)
    .option("upperBound", 1000000)
    .option("numPartitions", 8)
    .load()
)
df.show(1)
# Out:
# +-----+--------------------+--------------------+-------------+---------+-----+--------+-----+-------------+-----+-----------+------------+-----------+
# |Index|                Name|         Description|        Brand| Category|Price|Currency|Stock|          EAN|Color|       Size|Availability|Internal ID|
# +-----+--------------------+--------------------+-------------+---------+-----+--------+-----+-------------+-----+-----------+------------+-----------+
# |86152|Fast Lock Freezer...|Free position we ...|Avery-Barnett|Furniture|  938|     USD|  516|8429788643315| Navy|Extra Large|   backorder|         16|
# +-----+--------------------+--------------------+-------------+---------+-----+--------+-----+-------------+-----+-----------+------------+-----------+
# only showing top 1 row

# %% [markdown]
# #### Using SQL Query Instead of Table

# %%
query = "(SELECT * FROM myschema.products limit 1) AS tmp"

df = spark.read.jdbc(
    url=jdbc_url,
    table=query,
    properties=properties
)

df.show(1)
# Out:
# +------+--------------------+--------------------+---------------+--------+-----+--------+-----+-------------+------+----------+------------+-----------+
# | Index|                Name|         Description|          Brand|Category|Price|Currency|Stock|          EAN| Color|      Size|Availability|Internal ID|
# +------+--------------------+--------------------+---------------+--------+-----+--------+-----+-------------+------+----------+------------+-----------+
# |769551|Advanced Scale He...|Specific simple r...|Barton-Arellano| Cycling|  926|     USD|  648|1571405406951|Tomato|100x200 mm|    in_stock|         33|
# +------+--------------------+--------------------+---------------+--------+-----+--------+-----+-------------+------+----------+------------+-----------+

# %% [markdown]
# # # List Tables in PostgreSQL Using PySpark

# %%
query = """
(
SELECT table_name
FROM information_schema.tables
WHERE table_schema = 'myschema'
) AS tbl
"""

df = spark.read.jdbc(
    url=jdbc_url,
    table=query,
    properties=properties
)
df.show()
# Out:
# +----------------+
# |      table_name|
# +----------------+
# |        products|
# |     products_1m|
# |  salesrecords1m|
# |flight_data_2010|
# |flight_data_2015|
# +----------------+

# %%
tables = [row.table_name for row in df.collect()]
print(tables)
# Out:
# ['products', 'products_1m', 'salesrecords1m', 'flight_data_2010', 'flight_data_2015']

# %%
for row in df.collect():
    table_name = row["table_name"]

    df = spark.read.jdbc(
        url=jdbc_url,
        table=f"myschema.{table_name}",
        properties=properties
    )

    print(f"Read Table: {table_name}")
    print(f"Total Records: {df.count()}")
    df.show(2)
# Out:
# Read Table: products
# Total Records: 1000000
# +------+--------------------+--------------------+---------------+---------------+-----+--------+-----+-------------+------+----------+------------+-----------+
# | Index|                Name|         Description|          Brand|       Category|Price|Currency|Stock|          EAN| Color|      Size|Availability|Internal ID|
# +------+--------------------+--------------------+---------------+---------------+-----+--------+-----+-------------+------+----------+------------+-----------+
# |769551|Advanced Scale He...|Specific simple r...|Barton-Arellano|        Cycling|  926|     USD|  648|1571405406951|Tomato|100x200 mm|    in_stock|         33|
# |769552|   Mouse Radio Light|   Brother see page.|     Massey LLC|Office Supplies|  590|     USD|  851|9832739851667|   Red|     Small|    in_stock|         12|
# +------+--------------------+--------------------+---------------+---------------+-----+--------+-----+-------------+------+----------+------------+-----------+
# only showing top 2 rows
#
# Read Table: products_1m
# Total Records: 1000000
# +------+-----------------+--------------------+--------------------+---------------+-----+--------+-----+-------------+---------+--------+------------+-----------+
# | Index|             Name|         Description|               Brand|       Category|Price|Currency|Stock|          EAN|    Color|    Size|Availability|Internal_ID|
# +------+-----------------+--------------------+--------------------+---------------+-----+--------+-----+-------------+---------+--------+------------+-----------+
# |342301|            Clock|Positive media en...|Green, Wang and O...|Office Supplies|   12|     USD|  199|8165002716471|DarkGreen|   Large|    in_stock|         35|
# |342302|Fast Thermostat X|Choose news prove...|          Cherry Ltd|    Team Sports|  929|     USD|  300|1660886779712|  DimGray|50x70 cm|    in_stock|          8|
# +------+-----------------+--------------------+--------------------+---------------+-----+--------+-----+-------------+---------+--------+------------+-----------+
# only showing top 2 rows
#
# Read Table: salesrecords1m
# Total Records: 1000000
# +------+-------+---------------+-------------+--------------+----------+---------+---------+----------+----------+---------+-------------+----------+------------+
# |Region|Country|      Item_Type|Sales_Channel|Order_Priority|Order_Date| Order_ID|Ship_Date|Units_Sold|Unit_Price|Unit_Cost|Total_Revenue|Total_Cost|Total_Profit|
# +------+-------+---------------+-------------+--------------+----------+---------+---------+----------+----------+---------+-------------+----------+------------+
# |Europe| Monaco|Office Supplies|      Offline|             L| 8/15/2013|355756890|9/28/2013|      5224|    651.21|   524.96|   3401921.04|2742391.04|    659530.0|
# |  Asia| Brunei|     Vegetables|       Online|             M| 2/13/2011|652779567| 3/3/2011|       835|    154.06|    90.93|     128640.1|  75926.55|    52713.55|
# +------+-------+---------------+-------------+--------------+----------+---------+---------+----------+----------+---------+-------------+----------+------------+
# only showing top 2 rows
#
# Read Table: flight_data_2010
# Total Records: 255
# +-----------------+-------------------+-----+
# |DEST_COUNTRY_NAME|ORIGIN_COUNTRY_NAME|count|
# +-----------------+-------------------+-----+
# |    United States|            Romania|    1|
# |    United States|            Ireland|  264|
# +-----------------+-------------------+-----+
# only showing top 2 rows
#
# Read Table: flight_data_2015
# Total Records: 256
# +-----------------+-------------------+-----+
# |DEST_COUNTRY_NAME|ORIGIN_COUNTRY_NAME|count|
# +-----------------+-------------------+-----+
# |    United States|            Romania|   15|
# |    United States|            Croatia|    1|
# +-----------------+-------------------+-----+
# only showing top 2 rows

# %% [markdown]
# # # How PostgreSQL Handles Schemas:
#
# 1. Set search_path:
# - `SET search_path TO myschema;`
#
# # # Show Tables in PostgreSQL:
# 1. Using SQL Query:
#     ```
#     SELECT table_name
#     FROM information_schema.tables
#     WHERE table_schema = 'myschema';
#     ```
# 2. Using pg_catalog
#     ```
#     SELECT tablename
#     FROM pg_catalog.pg_tables
#     WHERE schemaname = 'myschema';
#     ```
# 3. List Tables From All Schemas:
#     ```
#     SELECT table_schema, table_name
#     FROM information_schema.tables
#     WHERE table_type = 'BASE TABLE'
#     ORDER BY table_schema, table_name;
#     ```
#
# # # To See All Schemas:
# `SELECT schema_name FROM information_schema.schemata;`
